# %% [markdown]
# TEMPLATE Report for analyzing the artifacts of the complete experiment

# %%
from IPython.display import Image, FileLink, display

# %% [markdown]
# Experiment.log

# %%
FileLink(path='../assets/model/experiment.log')
# Out:
# C:\Users\JeanCarlosMaia\Documents\GitHub\PERSONAL_DEV\boson-higgs\assets\model\experiment.log

# %% [markdown]
# #### ROC_AUC section
#
# -----
# ROC on Test

# %%
Image(filename='../assets/model/test_eval/roc_auc.png')

# %% [markdown]
# ROC on Train

# %%
Image(filename='../assets/model/train_eval/roc_auc.png')

# %% [markdown]
# #### F1 section
#
# -----
# F1 curve on test

# %%
Image(filename='../assets/model/test_eval/f1_threshold.png')

# %% [markdown]
# #### Calibration section
#
# -----
# Calibration curve on test

# %%
Image(filename='../assets/model/test_eval/calibration.png')

# %% [markdown]
# #### Precision Recall section
#
# -----
# Precision Recall curve on test

# %%
Image(filename='../assets/model/test_eval/precision_recall.png')
